# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("Accidents0515.csv")

# %%
pd.reset_option('display.max_columns')
pd.reset_option('display.precision')

pd.set_option('display.max_columns',50)
pd.set_option('display.precision',1)

pd.reset_option('display.max_rows')
pd.reset_option('display.precision')

pd.set_option('display.max_rows',1000)
pd.set_option('display.precision',1)

# %%
df.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0       -0.2
# 1  200501BS00002               524170.0                181650.0       -0.2
# 2  200501BS00003               524520.0                182240.0       -0.2
# 3  200501BS00004               526900.0                177530.0       -0.2
# 4  200501BS00005               528060.0                179040.0       -0.2
#
#    Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0      51.5             1                  2                   1
# 1      51.5             1                  3                   1
# 2      51.5             1                  3                   2
# 3      51.5             1                  3                   1
# 4      51.5             1                  3                   1
#
#    Number_of_Casualties        Date  Day_of_Week   Time  \
# 0                     1  04/01/2005            3  17:42
# ...

# %%
df.drop(['Accident_Index','Location_Easting_OSGR','Location_Northing_OSGR','Longitude','Latitude','Time','Local_Authority_(District)','Local_Authority_(Highway)','1st_Road_Class','1st_Road_Number','Junction_Detail','Junction_Control','2nd_Road_Class','2nd_Road_Number','Pedestrian_Crossing-Human_Control','Pedestrian_Crossing-Physical_Facilities','Special_Conditions_at_Site','Carriageway_Hazards','LSOA_of_Accident_Location'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1780653 entries, 0 to 1780652
# Data columns (total 13 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   Police_Force                                 int64
#  1   Accident_Severity                            int64
#  2   Number_of_Vehicles                           int64
#  3   Number_of_Casualties                         int64
#  4   Date                                         object
#  5   Day_of_Week                                  int64
#  6   Road_Type                                    int64
#  7   Speed_limit                                  int64
#  8   Light_Conditions                             int64
#  9   Weather_Conditions                           int64
#  10  Road_Surface_Conditions                      int64
#  11  Urban_or_Rural_Area                          int64
#  12  Did_Police_Officer_Attend_Scene_of_Accident  int64
# ...

# %%
# Separate the year from the date column
df['Year'] = pd.DatetimeIndex(df['Date']).year

# df['month'] = pd.DatetimeIndex(df['date']).month
# Display the data
df
# Out:
#          Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0                   1                  2                   1
# 1                   1                  3                   1
# 2                   1                  3                   2
# 3                   1                  3                   1
# 4                   1                  3                   1
# ...               ...                ...                 ...
# 1780648            98                  3                   3
# 1780649            98                  3                   2
# 1780650            98                  2                   1
# 1780651            98                  3                   3
# 1780652            98                  3                  13
#
#          Number_of_Casualties        Date  Day_of_Week  Road_Type  \
# 0                           1  04/01/2005            3          6
# 1                           1  05/01/2005            4          3
# ...

# %%
df_2015= df[df['Year'] == 2015]

# %%
df_2015.head()
# Out:
#          Police_Force  Accident_Severity  Number_of_Vehicles  \
# 1640597             1                  3                   1
# 1640598             1                  3                   1
# 1640599             1                  3                   1
# 1640600             1                  3                   1
# 1640601             1                  2                   2
#
#          Number_of_Casualties        Date  Day_of_Week  Road_Type  \
# 1640597                     1  12/01/2015            2          6
# 1640598                     1  12/01/2015            2          6
# 1640599                     1  12/01/2015            2          6
# 1640600                     1  13/01/2015            3          6
# 1640601                     1  09/01/2015            6          6
#
#          Speed_limit  Light_Conditions  Weather_Conditions  \
# 1640597           30                 4                   1
# 1640598           30                 1                   1
# ...

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140056 entries, 1640597 to 1780652
# Data columns (total 15 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Police_Force                                 140056 non-null  int64
#  1   Accident_Severity                            140056 non-null  int64
#  2   Number_of_Vehicles                           140056 non-null  int64
#  3   Number_of_Casualties                         140056 non-null  int64
#  4   Date                                         140056 non-null  object
#  5   Day_of_Week                                  140056 non-null  int64
#  6   Road_Type                                    140056 non-null  int64
#  7   Speed_limit                                  140056 non-null  int64
#  8   Light_Conditions                             140056 non-null  int64
# ...

# %%
scaler = StandardScaler()

# %%
df_2015[['Scaler_1', 'Scaler_2']] = scaler.fit_transform(df_2015[['Accident_Severity', 'Speed_limit']])

# %%
df_2015.head()
# Out:
#          Police_Force  Accident_Severity  Number_of_Vehicles  \
# 1640597             1                  3                   1
# 1640598             1                  3                   1
# 1640599             1                  3                   1
# 1640600             1                  3                   1
# 1640601             1                  2                   2
#
#          Number_of_Casualties        Date  Day_of_Week  Road_Type  \
# 1640597                     1  12/01/2015            2          6
# 1640598                     1  12/01/2015            2          6
# 1640599                     1  12/01/2015            2          6
# 1640600                     1  13/01/2015            3          6
# 1640601                     1  09/01/2015            6          6
#
#          Speed_limit  Light_Conditions  Weather_Conditions  \
# 1640597           30                 4                   1
# 1640598           30                 1                   1
# ...

# %%
X = df_2015[['Scaler_1','Scaler_2']]

# Applying KMeans to the dataset/ Creating the kmeans classifier
#kmeans = KMeans(n_clusters = 3, max_iter = 300, n_init = 10, random_state = 38)

# n_initial, default = 10, Number of time the k-means algorithm will be run with different centroid seeds. 
# The final results will be the best output of n_init consecutive runs in terms of inertia.
#y_kmeans = kmeans.fit_predict(x)

# %%
#ELBOW METHOD
def optimise_k_means (data, max_k) :
    means = []
    inertias =[]

    for k in range (1, max_k):
        kmeans = KMeans(n_clusters=k)
        kmeans.fit(data)

        means.append(k)
        inertias.append(kmeans.inertia_)

    #Generate the elbow plot
    fig = plt.subplots(figsize = (10,5))
    plt.plot(means, inertias, 'o-')
    plt.xlabel('Number of clusters')
    plt.ylabel('Inertia')
    plt.show()

# %%
optimise_k_means(X, 10)

# %%
kmeans = KMeans(n_clusters = 3)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
df_2015['kmeans_3'] = kmeans.labels_

# %%
df_2015.head()
# Out:
#          Police_Force  Accident_Severity  Number_of_Vehicles  \
# 1640597             1                  3                   1
# 1640598             1                  3                   1
# 1640599             1                  3                   1
# 1640600             1                  3                   1
# 1640601             1                  2                   2
#
#          Number_of_Casualties        Date  Day_of_Week  Road_Type  \
# 1640597                     1  12/01/2015            2          6
# 1640598                     1  12/01/2015            2          6
# 1640599                     1  12/01/2015            2          6
# 1640600                     1  13/01/2015            3          6
# 1640601                     1  09/01/2015            6          6
#
#          Speed_limit  Light_Conditions  Weather_Conditions  \
# 1640597           30                 4                   1
# 1640598           30                 1                   1
# ...

# %%
#Plotting the result
plt.scatter(x = df_2015['Accident_Severity'], y = df_2015['Speed_limit'], c = df_2015['kmeans_3']);
plt.show()

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
kmeans.cluster_centers_
# Out:
# array([[ 2.76315881, 63.35318912,  1.52635246,  1.44240081],
#        [ 2.85932709, 29.54248296,  1.24689097,  1.25090503],
#        [ 2.81301279, 43.22737965,  1.44953813,  1.32090195]])

# %%
kmeans.inertia_
# Out:
# 1583135.061408642

# %%
# Visualising the clusters using scatter() method
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'red', label = 'Cluster1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'blue', label = 'Cluster2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'green', label = 'Cluster3')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 150, c = 'yellow', label = 'Centroids')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

# A legend is an area describing the elements of the graph. In the matplotlib library, there's a function called legend() 
# which is used to Place a legend on the axes.
plt.legend( loc ="best")
